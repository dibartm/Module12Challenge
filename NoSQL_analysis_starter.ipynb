# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'uk_food')

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
establishments.find({'scores.Hygiene':20}) 
# Use count_documents to display the number of documents in the result
establishments.count_documents({'scores.Hygiene':20}) 

# Display the first document in the results using pprint
# Out:
# 41

# %%
# Convert the result to a Pandas DataFrame
df = pd.DataFrame(establishments.find({'scores.Hygiene':20}))
# Display the number of rows in the DataFrame
df.shape
# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  646d212f527615e99c4bcc37   110681                  0
# 1  646d212f527615e99c4bcfb6   612039                  0
# 2  646d2130527615e99c4bd2c0   730933                  0
# 3  646d2130527615e99c4bd4ae   172735                  0
# 4  646d2130527615e99c4bd4c2   172953                  0
# 5  646d2130527615e99c4bde5d   512854                  0
# 6  646d2130527615e99c4be07f  1537089                  0
# 7  646d2131527615e99c4bf5aa   155648                  0
# 8  646d2131527615e99c4bf9eb  1012883                  0
# 9  646d2131527615e99c4c0200   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# ...

# %%
df.columns
# Out:
# Index(['_id', 'FHRSID', 'ChangesByServerID', 'LocalAuthorityBusinessID',
#        'BusinessName', 'BusinessType', 'BusinessTypeID', 'AddressLine1',
#        'AddressLine2', 'AddressLine3', 'AddressLine4', 'PostCode', 'Phone',
#        'RatingValue', 'RatingKey', 'RatingDate', 'LocalAuthorityCode',
#        'LocalAuthorityName', 'LocalAuthorityWebSite',
#        'LocalAuthorityEmailAddress', 'scores', 'SchemeType', 'geocode',
#        'RightToReply', 'Distance', 'NewRatingPending', 'meta', 'links'],
#       dtype='object')

# %%
df[['BusinessName', 'BusinessType', 'BusinessTypeID', 'AddressLine1',
       'AddressLine2', 'AddressLine3', 'AddressLine4','LocalAuthorityName', 'RatingValue']]
# Out:
#                                          BusinessName  \
# 0                                 The Chase Rest Home
# 1                                          Brenalwood
# 2                                       Melrose Hotel
# 3                                       Seaford Pizza
# 4                                       Golden Palace
# 5                                    Ashby's Butchers
# 6                           South Sea Express Cuisine
# 7                                       Golden Palace
# 8                                      The Tulip Tree
# 9                                               F & S
# 10                                          Longhouse
# 11  Westview Playgroup Based At Downsview Comm Pri...
# 12                        Whatever The Weather Coffee
# 13                        Kings Restaurant (Oriental)
# 14                                            Xich Lo
# 15      Asian Supermarket Ltd: T/A Best Food Wine Ltd
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {'RatingValue':'5','RatingValue':'4'}
establishments.find(query)
# Use count_documents to display the number of documents in the result
establishments.count_documents(query)
# Display the first document in the results using pprint
# Out:
# 5441

# %%
# Convert the result to a Pandas DataFrame
gte4df=pd.DataFrame(establishments.find(query))
gte4df
# Display the number of rows in the DataFrame
gte4df.shape
# Display the first 10 rows of the DataFrame
gte4df.head(10)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  646d212e527615e99c4bb104   647177                  0
# 1  646d212e527615e99c4bb10c   987206                  0
# 2  646d212e527615e99c4bb10e   805702                  0
# 3  646d212e527615e99c4bb119  1396944                  0
# 4  646d212e527615e99c4bb123  1058636                  0
# 5  646d212e527615e99c4bb126  1138444                  0
# 6  646d212e527615e99c4bb127   865873                  0
# 7  646d212e527615e99c4bb153   505847                  0
# 8  646d212e527615e99c4bb154  1241756                  0
# 9  646d212e527615e99c4bb159   703619                  0
#
#   LocalAuthorityBusinessID                BusinessName  \
# 0             PI/000041489         Wear Bay Bowls Club
# 1             PI/000075655            The Ships Galley
# 2             PI/000073219    Dr Legumes - Harbour Arm
# 3             PI/000078122                      Dino's
# 4             PI/000076450                      Babaji
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score
establishments.find_one({'BusinessName': 'Penang Flavours'})['geocode']['longitude']


degree_search = 0.01
latitude = establishments.find_one({'BusinessName': 'Penang Flavours'})['geocode']['latitude']
longitude = establishments.find_one({'BusinessName': 'Penang Flavours'})['geocode']['longitude']


query = {
     'geocode.latitude': {'$gte': latitude - degree_search, '$lte': latitude + degree_search},
     'geocode.longitude': {'$gte': longitude - degree_search, '$lte': longitude + degree_search},
    'RatingValue': '5'
}
sort = establishments.find(query).sort([('scores.Hygiene', -1)])
# Print the results
for est in sort:
    print(est)
# Out:
# {'_id': ObjectId('646d2132527615e99c4c2442'), 'FHRSID': 1069652, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000206841', 'BusinessName': 'TIWA N TIWA African Restaurant Ltd', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1, 'AddressLine1': '152 Plumstead High Street', 'AddressLine2': '', 'AddressLine3': 'Plumstead', 'AddressLine4': 'Greenwich', 'PostCode': 'SE18 1JQ', 'Phone': '', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2020-10-24T00:00:00', 'LocalAuthorityCode': '511', 'LocalAuthorityName': 'Greenwich', 'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk', 'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk', 'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 0.0927429, 'latitude': 51.4870351}, 'RightToReply': '', 'Distance': 4646.930146257832, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0
# ...

# %%
# Convert result to Pandas DataFrame
close_by_df = pd.DataFrame(establishments.find(query).sort([('scores.Hygiene', -1)]))

# %%
close_by_df
# Out:
#                          _id   FHRSID  ChangesByServerID  \
# 0   646d2132527615e99c4c2442  1069652                  0
# 1   646d2132527615e99c4c2521   694606                  0
# 2   646d2132527615e99c4c2534   695287                  0
# 3   646d2132527615e99c4c2550   695566                  0
# 4   646d2132527615e99c4c2558   695033                  0
# ..                       ...      ...                ...
# 82  646d2132527615e99c4c2867   694051                  0
# 83  646d2132527615e99c4c288a  1112594                  0
# 84  646d2132527615e99c4c2896  1468524                  0
# 85  646d2132527615e99c4c28c7  1243199                  0
# 86  646d2132527615e99c4c28d8  1388277                  0
#
#    LocalAuthorityBusinessID                        BusinessName  \
# 0              PI/000206841  TIWA N TIWA African Restaurant Ltd
# 1              PI/000116584                Fineway Cash & Carry
# 2              PI/000182135                   Lucky Food & Wine
# ...

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
hygiene0 = {'$match':{'scores.Hygiene':0}}
# 2. Groups the matches by Local Authority
groupla = {'$group':{'_id':'$LocalAuthorityName','count':{'$sum':1}}}
# 3. Sorts the matches from highest to lowest
sort_matches = {'$sort':{'count':-1}}
# Print the number of documents in the result
pipeline = [hygiene0,groupla,sort_matches]
# Print the first 10 results
results = establishments.aggregate(pipeline)
for est in results :
    print(est)
# Out:
# {'_id': 'Thanet', 'count': 1130}
# {'_id': 'Greenwich', 'count': 882}
# {'_id': 'Maidstone', 'count': 713}
# {'_id': 'Newham', 'count': 711}
# {'_id': 'Swale', 'count': 686}
# {'_id': 'Chelmsford', 'count': 680}
# {'_id': 'Medway', 'count': 672}
# {'_id': 'Bexley', 'count': 607}
# {'_id': 'Southend-On-Sea', 'count': 586}
# {'_id': 'Tendring', 'count': 542}
# {'_id': 'Colchester', 'count': 498}
# {'_id': 'Tunbridge Wells', 'count': 491}
# {'_id': 'Folkestone and Hythe', 'count': 480}
# {'_id': 'Eastbourne', 'count': 478}
# {'_id': 'Hastings', 'count': 464}
# {'_id': 'Bromley', 'count': 460}
# {'_id': 'Ashford', 'count': 427}
# {'_id': 'Havering', 'count': 397}
# {'_id': 'Dartford', 'count': 383}
# {'_id': 'Braintree', 'count': 382}
# {'_id': 'Basildon', 'count': 362}
# {'_id': 'Gravesham', 'count': 339}
# {'_id': 'Tonbridge and Malling', 'count': 325}
# {'_id': 'Thurrock', 'count': 313}
# {'_id': 'Barking and Dagenham', 'count': 301}
# {'_id': 'Canterbury City', 'count': 298}
# ...

# %%
# Convert the result to a Pandas DataFrame
neighborhoods = pd.DataFrame(establishments.aggregate(pipeline))
neighborhoods
# Display the number of rows in the DataFrame
print(neighborhoods.shape[0])
# Display the first 10 rows of the DataFrame
neighborhoods.head(10)
# Out:
# 55
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
